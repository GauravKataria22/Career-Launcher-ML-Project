# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Module 5 submission by Gaurav Kataria
#Problem Statment 5.1
#To do -
# 1. calculate the mean daily return and daily standard deviation of returns
# 2. calculate the mean expected annual return and volatility of the single selected stock

# %%
data = pd.read_csv(r'C:\Users\gaura\Desktop\_\Week2.csv')
data.head()
# Out:
#    Unnamed: 0     Symbol Series        Date  Prev Close  Open Price  \
# 0           0  BOMDYEING     EQ  2017-05-15       83.00       83.15
# 1           1  BOMDYEING     EQ  2017-05-16       82.20       81.90
# 2           2  BOMDYEING     EQ  2017-05-17       83.40       82.55
# 3           3  BOMDYEING     EQ  2017-05-18       82.25       80.85
# 4           4  BOMDYEING     EQ  2017-05-19       78.95       79.75
#
#    High Price  Low Price  Last Price  Close Price  ...  Total Traded Quantity  \
# 0       83.75      81.90       82.15        82.20  ...                1553427
# 1       84.00      81.75       83.80        83.40  ...                2149649
# 2       83.80      82.05       82.25        82.25  ...                1267468
# 3       81.85      78.55       78.90        78.95  ...                1156424
# 4       80.35      76.35       77.30        77.15  ...                1444416
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  year  \
# 0  1.282609e+08           8074           479867                   30.89  2017
# 1  1.781606e+08           9804           561852                   26.14  2017
# 2  1.048354e+08           7220           395417                   31.20  2017
# 3  9.286568e+07           7001           538431                   46.56  2017
# 4  1.127716e+08           7588           518874                   35.92  2017
#
#    month       VWAP  Day_Perc_Change                Trend
# 0      5  82.200000         0.000000  Slight or No change
# 1      5  82.896604         0.014599  Slight or No change
# 2      5  82.731723        -0.013789  Slight or No change
# 3      5  82.017948        -0.040122  Slight or No change
# 4      5  81.089275        -0.022799  Slight or No change
#
# [5 rows x 21 columns]

# %%
mean_daily_return = np.mean(data['Day_Perc_Change'])
std_daily_return = np.std(data['Day_Perc_Change'])
annual_return = mean_daily_return * 252
volatility = std_daily_return * np.sqrt(252)
print(f'The daily return of this stock on an average is: {mean_daily_return}')
print(f'The standard deviation of daily return of this stock is: {std_daily_return}')
print(f'The annual return of this stock is: {annual_return}')
print(f'The Volatility of this stock is: {volatility}')
# Out:
# The daily return of this stock on an average is: 0.0020298769132150144
# The standard deviation of daily return of this stock is: 0.046695423785624385
# The annual return of this stock is: 0.5115289821301836
# The Volatility of this stock is: 0.7412668722091943

# %%
#Problem Statment 5.2
#To do -
# 1. Choose any 5 stocks, calculate the annual returns and volatility of the entire portfolio

# %%
jet = pd.read_csv(r'C:\Users\gaura\Desktop\_\smallcap\Small_Cap\JETAIRWAYS.csv')
jet
# Out:
#          Symbol Series         Date  Prev Close  Open Price  High Price  \
# 0    JETAIRWAYS     EQ  15-May-2017      519.45      520.00      533.40
# 1    JETAIRWAYS     EQ  16-May-2017      527.50      527.00      536.50
# 2    JETAIRWAYS     EQ  17-May-2017      534.15      532.00      534.75
# 3    JETAIRWAYS     EQ  18-May-2017      528.90      525.15      538.60
# 4    JETAIRWAYS     EQ  19-May-2017      522.70      525.60      532.90
# ..          ...    ...          ...         ...         ...         ...
# 489  JETAIRWAYS     EQ  07-May-2019      133.40      129.70      132.90
# 490  JETAIRWAYS     EQ  08-May-2019      127.30      127.90      136.00
# 491  JETAIRWAYS     EQ  09-May-2019      131.35      133.50      149.30
# 492  JETAIRWAYS     EQ  10-May-2019      147.40      150.20      157.90
# 493  JETAIRWAYS     EQ  13-May-2019      151.75      136.60      147.80
#
#      Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0       517.10      527.80       527.50         526.08                1837033
# 1       524.65      534.00       534.15         531.79                1382182
# 2       526.20      530.00       528.90         529.75                 690466
# 3       517.50      517.70       522.70         529.55                1701102
# 4       517.45      521.00       520.40         524.69                1272799
# ..         ...         ...          ...            ...                    ...
# 489     121.00      126.00       127.30         128.62               12212871
# 490     124.15      131.95       131.35         131.47               21943764
# 491     131.65      147.95       147.40         142.76               34122898
# 492     145.30      146.00       151.75         152.92               22274234
# 493     134.40      139.00       139.10         142.01               16971715
#
#          Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# 0    9.664298e+08          25433           430754                   23.45
# 1    7.350363e+08          23991           284837                   20.61
# 2    3.657742e+08          10219            53551                    7.76
# 3    9.008102e+08          25651           309608                   18.20
# 4    6.678247e+08          20409           257037                   20.19
# ..            ...            ...              ...                     ...
# 489  1.570824e+09          89280           681164                    5.58
# 490  2.884869e+09         165672           833160                    3.80
# 491  4.871547e+09         223239          1497595                    4.39
# 492  3.406187e+09         193811          1431777                    6.43
# 493  2.410211e+09         145387           792138                    4.67
#
# [494 rows x 15 columns]

# %%
ircon = pd.read_csv(r'C:\Users\gaura\Desktop\_\smallcap\Small_Cap\IRCON.csv')
ircon
# Out:
#     Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 0    IRCON     EQ  28-Sep-2018      475.00      412.00      465.00     409.10
# 1    IRCON     EQ  01-Oct-2018      415.30      418.10      434.85     406.60
# 2    IRCON     EQ  03-Oct-2018      427.00      431.35      437.85     418.55
# 3    IRCON     EQ  04-Oct-2018      421.40      419.00      419.00     404.00
# 4    IRCON     EQ  05-Oct-2018      407.10      407.00      409.10     388.30
# ..     ...    ...          ...         ...         ...         ...        ...
# 146  IRCON     EQ  07-May-2019      403.75      407.00      407.00     394.00
# 147  IRCON     EQ  08-May-2019      398.20      392.00      398.95     392.00
# 148  IRCON     EQ  09-May-2019      394.30      393.95      403.95     393.95
# 149  IRCON     EQ  10-May-2019      399.95      396.00      399.80     394.00
# 150  IRCON     EQ  13-May-2019      395.45      394.20      403.85     382.15
#
#      Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0        412.95       415.30         436.73                5675479
# 1        428.25       427.00         419.97                 624624
# 2        419.05       421.40         427.59                 279765
# 3        405.45       407.10         410.83                 232364
# 4        397.95       399.80         396.40                 373530
# ..          ...          ...            ...                    ...
# 146      395.00       398.20         401.84                  14950
# 147      393.50       394.30         395.88                  11563
# 148      399.80       399.95         398.71                  42142
# 149      395.00       395.45         396.12                   8761
# 150      382.25       385.75         392.29                  31907
#
#          Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# 0    2.478674e+09         182952          1617374                   28.50
# 1    2.623233e+08          20363           148088                   23.71
# 2    1.196258e+08           9172           110748                   39.59
# 3    9.546208e+07          10440           111715                   48.08
# 4    1.480676e+08           9636           203317                   54.43
# ..            ...            ...              ...                     ...
# 146  6.007548e+06           1947             9588                   64.13
# 147  4.577563e+06            460             6754                   58.41
# 148  1.680232e+07            685            27694                   65.72
# 149  3.470424e+06            605             4728                   53.97
# 150  1.251688e+07           1837            14162                   44.39
#
# [151 rows x 15 columns]

# %%
jk = pd.read_csv(r'C:\Users\gaura\Desktop\_\smallcap\Small_Cap\JKLAKSHMI.csv')
jk
# Out:
#         Symbol Series         Date  Prev Close  Open Price  High Price  \
# 0    JKLAKSHMI     EQ  15-May-2017      504.30      504.00      519.40
# 1    JKLAKSHMI     EQ  16-May-2017      510.80      514.60      532.95
# 2    JKLAKSHMI     EQ  17-May-2017      527.50      530.90      536.95
# 3    JKLAKSHMI     EQ  18-May-2017      516.20      491.70      504.00
# 4    JKLAKSHMI     EQ  19-May-2017      478.95      481.80      488.85
# ..         ...    ...          ...         ...         ...         ...
# 489  JKLAKSHMI     EQ  07-May-2019      354.55      351.30      374.50
# 490  JKLAKSHMI     EQ  08-May-2019      367.95      369.70      371.65
# 491  JKLAKSHMI     EQ  09-May-2019      352.20      352.75      355.30
# 492  JKLAKSHMI     EQ  10-May-2019      353.00      353.25      354.10
# 493  JKLAKSHMI     EQ  13-May-2019      342.10      339.00      344.85
#
#      Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0       504.00      511.00       510.80         512.21                  65942
# 1       513.00      532.00       527.50         521.11                 161032
# 2       513.00      513.90       516.20         523.78                  95207
# 3       472.00      484.55       478.95         482.76                 493737
# 4       465.00      469.00       469.55         483.69                 334922
# ..         ...         ...          ...            ...                    ...
# 489     351.30      366.00       367.95         368.60                  93454
# 490     350.85      352.00       352.20         355.95                  49042
# 491     350.15      354.00       353.00         353.57                  34791
# 492     340.50      341.00       342.10         345.79                  42127
# 493     333.50      340.00       340.05         339.54                  29826
#
#          Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# 0    3.377596e+07           2066            34858                   52.86
# 1    8.391606e+07           4959            94000                   58.37
# 2    4.986782e+07           2878            57507                   60.40
# 3    2.383550e+08          14686           243734                   49.37
# 4    1.619969e+08          15246           248638                   74.24
# ..            ...            ...              ...                     ...
# 489  3.444681e+07           3734            57074                   61.07
# 490  1.745646e+07           2646            25854                   52.72
# 491  1.230097e+07           1073            16980                   48.81
# 492  1.456710e+07           1775            21103                   50.09
# 493  1.012704e+07           1247            16819                   56.39
#
# [494 rows x 15 columns]

# %%
lt = pd.read_csv(r'C:\Users\gaura\Desktop\_\smallcap\Small_Cap\LEMONTREE.csv')
lt
# Out:
#         Symbol Series         Date  Prev Close  Open Price  High Price  \
# 0    LEMONTREE     EQ  09-Apr-2018       56.00       61.60       73.90
# 1    LEMONTREE     EQ  10-Apr-2018       71.65       69.85       71.50
# 2    LEMONTREE     EQ  11-Apr-2018       66.85       67.25       69.70
# 3    LEMONTREE     EQ  12-Apr-2018       66.95       67.10       67.70
# 4    LEMONTREE     EQ  13-Apr-2018       66.40       66.70       68.20
# ..         ...    ...          ...         ...         ...         ...
# 265  LEMONTREE     EQ  07-May-2019       72.95       72.80       74.60
# 266  LEMONTREE     EQ  08-May-2019       72.90       72.90       73.00
# 267  LEMONTREE     EQ  09-May-2019       71.65       71.00       71.85
# 268  LEMONTREE     EQ  10-May-2019       71.25       71.00       72.90
# 269  LEMONTREE     EQ  13-May-2019       71.35       71.00       71.30
#
#      Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0        57.25       72.30        71.65          65.59               67619635
# 1        65.40       66.50        66.85          68.42               15217104
# 2        66.05       66.95        66.95          67.69                9094509
# 3        65.10       66.50        66.40          66.44                2408408
# 4        66.50       67.60        67.70          67.56                2406014
# ..         ...         ...          ...            ...                    ...
# 265      72.50       72.70        72.90          73.49                 233538
# 266      70.10       71.60        71.65          71.36                 343907
# 267      70.00       71.45        71.25          70.69                 219913
# 268      70.80       71.20        71.35          71.55                 156657
# 269      70.00       70.40        70.25          70.40                 152710
#
#          Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# 0    4.434900e+09         263630         13918070                   20.58
# 1    1.041159e+09          87183          3186294                   20.94
# 2    6.156216e+08          44895          2323539                   25.55
# 3    1.600220e+08          14777           681080                   28.28
# 4    1.625400e+08          20955           994028                   41.31
# ..            ...            ...              ...                     ...
# 265  1.716169e+07           4634           141921                   60.77
# 266  2.454240e+07           7449           213025                   61.94
# 267  1.554673e+07           5133           119405                   54.30
# 268  1.120904e+07           1369            86735                   55.37
# 269  1.075013e+07           2235            78786                   51.59
#
# [270 rows x 15 columns]

# %%
vk = pd.read_csv(r'C:\Users\gaura\Desktop\_\smallcap\Small_Cap\VENKEYS.csv')
vk
# Out:
#       Symbol Series         Date  Prev Close  Open Price  High Price  \
# 0    VENKEYS     EQ  15-May-2017     1228.40     1167.00     1244.70
# 1    VENKEYS     EQ  16-May-2017     1169.70     1169.70     1205.65
# 2    VENKEYS     EQ  17-May-2017     1177.00     1177.00     1209.95
# 3    VENKEYS     EQ  18-May-2017     1188.00     1183.00     1188.00
# 4    VENKEYS     EQ  19-May-2017     1156.90     1161.70     1181.00
# ..       ...    ...          ...         ...         ...         ...
# 489  VENKEYS     EQ  07-May-2019     2014.90     2025.00     2057.80
# 490  VENKEYS     EQ  08-May-2019     2000.45     1997.90     2000.45
# 491  VENKEYS     EQ  09-May-2019     1956.70     1959.75     1977.95
# 492  VENKEYS     EQ  10-May-2019     1930.10     1935.00     1962.90
# 493  VENKEYS     EQ  13-May-2019     1820.65     1810.00     1810.00
#
#      Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0      1167.00     1172.00      1169.70        1189.59                  99659
# 1      1135.00     1183.00      1177.00        1172.48                  61572
# 2      1174.20     1188.20      1188.00        1194.72                  60769
# 3      1150.00     1157.00      1156.90        1169.84                  28629
# 4      1141.15     1162.00      1161.65        1163.78                  28520
# ..         ...         ...          ...            ...                    ...
# 489    1990.00     2013.80      2000.45        2027.54                  36714
# 490    1950.00     1956.75      1956.70        1971.81                  29889
# 491    1921.20     1925.05      1930.10        1946.26                  35929
# 492    1802.20     1810.00      1820.65        1850.03                 301338
# 493    1700.00     1701.00      1706.75        1746.56                 105506
#
#          Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# 0    1.185535e+08           5436            40813                   40.95
# 1    7.219211e+07           4011            22051                   35.81
# 2    7.260207e+07           2904            17361                   28.57
# 3    3.349137e+07           1699            12506                   43.68
# 4    3.319106e+07           1538            11738                   41.16
# ..            ...            ...              ...                     ...
# 489  7.443911e+07           4129            11592                   31.57
# 490  5.893555e+07           3671            12658                   42.35
# 491  6.992725e+07           4586            13245                   36.86
# 492  5.574854e+08          25294            48819                   16.20
# 493  1.842727e+08          10731            36173                   34.29
#
# [494 rows x 15 columns]

# %%
portfolio = pd.DataFrame()
portfolio['jet'],portfolio['ircon'],portfolio['jk'],portfolio['lt'],portfolio['vk'] = jet['Close Price'],ircon['Close Price'],jk['Close Price'],lt['Close Price'],vk['Close Price']
print(portfolio.shape)
# Out:
# (494, 5)

# %%
portfolio.head()
# Out:
#       jet  ircon      jk     lt       vk
# 0  527.50  415.3  510.80  71.65  1169.70
# 1  534.15  427.0  527.50  66.85  1177.00
# 2  528.90  421.4  516.20  66.95  1188.00
# 3  522.70  407.1  478.95  66.40  1156.90
# 4  520.40  399.8  469.55  67.70  1161.65

# %%
portfolio['Daily Return Stock 1 %'] = portfolio['jet'].pct_change() * 100
portfolio['Daily Return Stock 2 %'] = portfolio['ircon'].pct_change() * 100
portfolio['Daily Return Stock 3 %'] = portfolio['jk'].pct_change() * 100
portfolio['Daily Return Stock 4 %'] = portfolio['lt'].pct_change() * 100
portfolio['Daily Return Stock 5 %'] = portfolio['vk'].pct_change() * 100

# %%
portfolio.fillna(0,inplace=True)
portfolio.head()
# Out:
#       jet  ircon      jk     lt       vk  Daily Return Stock 1 %  \
# 0  527.50  415.3  510.80  71.65  1169.70                0.000000
# 1  534.15  427.0  527.50  66.85  1177.00                1.260664
# 2  528.90  421.4  516.20  66.95  1188.00               -0.982870
# 3  522.70  407.1  478.95  66.40  1156.90               -1.172244
# 4  520.40  399.8  469.55  67.70  1161.65               -0.440023
#
#    Daily Return Stock 2 %  Daily Return Stock 3 %  Daily Return Stock 4 %  \
# 0                0.000000                0.000000                0.000000
# 1                2.817241                3.269381               -6.699232
# 2               -1.311475               -2.142180                0.149589
# 3               -3.393450               -7.216195               -0.821509
# 4               -1.793171               -1.962627                1.957831
#
#    Daily Return Stock 5 %
# 0                0.000000
# 1                0.624092
# 2                0.934579
# 3               -2.617845
# 4                0.410580

# %%
#Annual returns of portfolio
annual_returns = {}
for i in range(1,6):
    annual_returns['annual_mean_return_' + str(i)] = np.mean(portfolio[f'Daily Return Stock {str(i)} %'])*252

# %%
print(annual_returns.values())
# Out:
# dict_values([-48.00450781787351, -2.4060601870369376, -16.852327239948924, 3.092659526416562, 38.09379525876144])

# %%
total_port_annual_return = np.sum(list(annual_returns.values()))
total_port_annual_return = (total_port_annual_return*0.20)
print(f'The total annual return of portfolio is: {total_port_annual_return} %')
# Out:
# The total annual return of portfolio is: -5.215288091936272 %

# %%
# Annual variance fro each stock
annual_std = {}
for i in range(1,6):
    annual_std['annual_std_' + str(i)] = np.std(portfolio[f'Daily Return Stock {str(i)} %']) * np.sqrt(252)

# %%
annual_std.values()
# Out:
# dict_values([62.35890012785946, 16.560909009464435, 27.910179017542976, 28.896473385510305, 62.61129809711338])

# %%
annual_variance = map(lambda x: x**2,list(annual_std.values()))

# %%
annual_variance = list(annual_variance)

# %%
annual_variance
# Out:
# [3888.63242515635,
#  274.2637072197603,
#  778.9780927912963,
#  835.0061741195054,
#  3920.1746494055933]

# %%
portfolio.head()
# Out:
#       jet  ircon      jk     lt       vk  Daily Return Stock 1 %  \
# 0  527.50  415.3  510.80  71.65  1169.70                0.000000
# 1  534.15  427.0  527.50  66.85  1177.00                1.260664
# 2  528.90  421.4  516.20  66.95  1188.00               -0.982870
# 3  522.70  407.1  478.95  66.40  1156.90               -1.172244
# 4  520.40  399.8  469.55  67.70  1161.65               -0.440023
#
#    Daily Return Stock 2 %  Daily Return Stock 3 %  Daily Return Stock 4 %  \
# 0                0.000000                0.000000                0.000000
# 1                2.817241                3.269381               -6.699232
# 2               -1.311475               -2.142180                0.149589
# 3               -3.393450               -7.216195               -0.821509
# 4               -1.793171               -1.962627                1.957831
#
#    Daily Return Stock 5 %
# 0                0.000000
# 1                0.624092
# 2                0.934579
# 3               -2.617845
# 4                0.410580

# %%
#covariance for all stocks
cov = portfolio[['Daily Return Stock 1 %','Daily Return Stock 2 %','Daily Return Stock 3 %','Daily Return Stock 4 %','Daily Return Stock 5 %',]].cov()

# %%
cov
# Out:
#                         Daily Return Stock 1 %  Daily Return Stock 2 %  \
# Daily Return Stock 1 %               15.462381                0.001233
# Daily Return Stock 2 %                0.001233                1.090556
# Daily Return Stock 3 %                1.174846                0.140277
# Daily Return Stock 4 %                0.358216               -0.064135
# Daily Return Stock 5 %                2.286146               -0.135955
#
#                         Daily Return Stock 3 %  Daily Return Stock 4 %  \
# Daily Return Stock 1 %                1.174846                0.358216
# Daily Return Stock 2 %                0.140277               -0.064135
# Daily Return Stock 3 %                3.097453                0.042521
# Daily Return Stock 4 %                0.042521                3.320238
# Daily Return Stock 5 %                0.792525                0.301795
#
#                         Daily Return Stock 5 %
# Daily Return Stock 1 %                2.286146
# Daily Return Stock 2 %               -0.135955
# Daily Return Stock 3 %                0.792525
# Daily Return Stock 4 %                0.301795
# Daily Return Stock 5 %               15.587803

# %%
cov_arr = np.array(cov)

# %%
cov_arr
# Out:
# array([[ 1.54623814e+01,  1.23336631e-03,  1.17484594e+00,
#          3.58216276e-01,  2.28614580e+00],
#        [ 1.23336631e-03,  1.09055565e+00,  1.40276983e-01,
#         -6.41347673e-02, -1.35954873e-01],
#        [ 1.17484594e+00,  1.40276983e-01,  3.09745306e+00,
#          4.25214853e-02,  7.92524893e-01],
#        [ 3.58216276e-01, -6.41347673e-02,  4.25214853e-02,
#          3.32023769e+00,  3.01794703e-01],
#        [ 2.28614580e+00, -1.35954873e-01,  7.92524893e-01,
#          3.01794703e-01,  1.55878029e+01]])

# %%
cov_dict = {}
for i in range(0,5):
    for j in range(0,5):
        if(i<j):
            cov_dict[str(i) + '-' + str(j)] = cov_arr[i][j]

# %%
cov_dict
# Out:
# {'0-1': 0.0012333663060852089,
#  '0-2': 1.1748459364617208,
#  '0-3': 0.3582162757417855,
#  '0-4': 2.2861458048036885,
#  '1-2': 0.14027698335916974,
#  '1-3': -0.06413476726895051,
#  '1-4': -0.13595487344122126,
#  '2-3': 0.042521485250535895,
#  '2-4': 0.7925248930499385,
#  '3-4': 0.3017947033801023}

# %%
cov_dict.values()
# Out:
# dict_values([0.0012333663060852089, 1.1748459364617208, 0.3582162757417855, 2.2861458048036885, 0.14027698335916974, -0.06413476726895051, -0.13595487344122126, 0.042521485250535895, 0.7925248930499385, 0.3017947033801023])

# %%
sum_cov = 0
for value in cov_dict.values():
    sum_cov += value
sum_cov
# Out:
# 4.897469807642855

# %%
weight = 0.2
vol_sum = 0
for i in range(5):
    vol_sum += (weight ** 2) * (annual_variance[i])

volatility_port = vol_sum + ((2*weight*weight) * sum_cov) 
volatility_port = np.sqrt(volatility_port)

# %%
#Annual return and votality
print(f'The Total Annual Return of this Portfolio is: {np.round(total_port_annual_return,3)} %\nThe Total Volatility for this Portfolio is: {np.round(volatility_port,3)} %')
# Out:
# The Total Annual Return of this Portfolio is: -5.215 %
# The Total Volatility for this Portfolio is: 19.705 %

# %%
#5.3
# To do - 
# 1. Create a scatter plot for differing weights of the individual stocks in the portfolio

# %%
A = np.array(np.random.rand(494,5))
s = A
for i in range(len(s)):
    s[i] = s[i] * (1/np.sum(s[i]))
np.sum(s,axis=1)
s = pd.DataFrame(s)
s.head()
# Out:
#           0         1         2         3         4
# 0  0.289574  0.114300  0.162298  0.268076  0.165752
# 1  0.094274  0.358270  0.088908  0.439861  0.018686
# 2  0.439894  0.186630  0.004017  0.144474  0.224984
# 3  0.275464  0.018444  0.377480  0.214188  0.114425
# 4  0.293491  0.212108  0.054573  0.352857  0.086971

# %%
varying_portfolio = portfolio[['Daily Return Stock 1 %','Daily Return Stock 2 %','Daily Return Stock 3 %','Daily Return Stock 4 %','Daily Return Stock 5 %']]
varying_portfolio
# Out:
#      Daily Return Stock 1 %  Daily Return Stock 2 %  Daily Return Stock 3 %  \
# 0                  0.000000                0.000000                0.000000
# 1                  1.260664                2.817241                3.269381
# 2                 -0.982870               -1.311475               -2.142180
# 3                 -1.172244               -3.393450               -7.216195
# 4                 -0.440023               -1.793171               -1.962627
# ..                      ...                     ...                     ...
# 489               -4.572714                0.000000                3.779439
# 490                3.181461                0.000000               -4.280473
# 491               12.219262                0.000000                0.227144
# 492                2.951153                0.000000               -3.087819
# 493               -8.336079                0.000000               -0.599240
#
#      Daily Return Stock 4 %  Daily Return Stock 5 %
# 0                  0.000000                0.000000
# 1                 -6.699232                0.624092
# 2                  0.149589                0.934579
# 3                 -0.821509               -2.617845
# 4                  1.957831                0.410580
# ..                      ...                     ...
# 489                0.000000               -0.717157
# 490                0.000000               -2.187008
# 491                0.000000               -1.359432
# 492                0.000000               -5.670691
# 493                0.000000               -6.256007
#
# [494 rows x 5 columns]

# %%
s
# Out:
#             0         1         2         3         4
# 0    0.289574  0.114300  0.162298  0.268076  0.165752
# 1    0.094274  0.358270  0.088908  0.439861  0.018686
# 2    0.439894  0.186630  0.004017  0.144474  0.224984
# 3    0.275464  0.018444  0.377480  0.214188  0.114425
# 4    0.293491  0.212108  0.054573  0.352857  0.086971
# ..        ...       ...       ...       ...       ...
# 489  0.259599  0.039793  0.290816  0.408021  0.001771
# 490  0.352124  0.186521  0.061528  0.297706  0.102122
# 491  0.249646  0.315009  0.356654  0.016615  0.062076
# 492  0.096467  0.280684  0.162458  0.162922  0.297468
# 493  0.079332  0.188211  0.364574  0.176635  0.191247
#
# [494 rows x 5 columns]

# %%
s['Expected Return'] = 1.0
s['Volatility'] = 1.0
for i in s.index:
    s['Expected Return'][i] = np.mean(np.dot(np.array(varying_portfolio),(np.array(s.iloc[i,:-2])))) * 252
    s['Volatility'][i] = np.std(np.dot(np.array(varying_portfolio),(np.array(s.iloc[i,:-2])))) * np.sqrt(252)

# %%
s
# Out:
#             0         1         2         3         4  Expected Return  \
# 0    0.289574  0.114300  0.162298  0.268076  0.165752        -9.767760
# 1    0.094274  0.358270  0.088908  0.439861  0.018686        -4.813759
# 2    0.439894  0.186630  0.004017  0.144474  0.224984       -12.616344
# 3    0.275464  0.018444  0.377480  0.214188  0.114425       -14.608013
# 4    0.293491  0.212108  0.054573  0.352857  0.086971       -11.114617
# ..        ...       ...       ...       ...       ...              ...
# 489  0.259599  0.039793  0.290816  0.408021  0.001771       -16.129242
# 490  0.352124  0.186521  0.061528  0.297706  0.102122       -13.578325
# 491  0.249646  0.315009  0.356654  0.016615  0.062076       -16.336453
# 492  0.096467  0.280684  0.162458  0.162922  0.297468         3.791562
# 493  0.079332  0.188211  0.364574  0.176635  0.191247        -2.573509
#
#      Volatility
# 0     25.145147
# 1     15.898727
# 2     33.254646
# 3     25.040081
# 4     23.341986
# ..          ...
# 489   23.125186
# 490   26.226787
# 491   21.696810
# 492   22.709699
# 493   19.489421
#
# [494 rows x 7 columns]

# %%
import matplotlib.colors
my_cmap = matplotlib.colors.LinearSegmentedColormap.from_list("",["red","blue"])

# %%
plt.style.use('seaborn')
x,y = s['Volatility'],s['Expected Return']
plt.scatter(x,y,c=y/x,cmap = my_cmap)
plt.xlabel('Volatility')
plt.ylabel('Returns')

plt.show()

# %%
#5.4
# To do - 
# 1. Mark the 2 portfolios where 
#  Portfolio 1 - The Sharpe ratio is the highest 
#  Portfolio 2 - The volatility is the lowest.

# %%
np.argmin(s['Volatility'])
# Out:
# 32

# %%
a = []
for i in s.index:
    a.append(s['Expected Return'][i]/s['Volatility'][i])

np.argmax(a)
# Out:
# 194

# %%
plt.style.use('seaborn')
x,y = s['Volatility'],s['Expected Return']
plt.scatter(x,y,c=y/x,cmap = my_cmap)
plt.xlabel('Volatility')
plt.ylabel('Returns')
plt.scatter(s.iloc[32]['Volatility'],s.iloc[32]['Expected Return'],marker='*',c='black',s=300)
plt.scatter(s.iloc[194]['Volatility'],s.iloc[194]['Expected Return'],marker='*',c='black',s=200)

plt.show()
