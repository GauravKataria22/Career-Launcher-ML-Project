# %%
#Module 3 submission by Gaurav Kataria
#Problem Statement 3.1
#To do - 
# 1. Import gold.csv
# 2. Explore thhe dataframe
# 3. Using linear regression, find the coefficiants of the inputs and using the same trained model complete the entire column
# 4. Fit the other column as well
# 5. Check if the predictions are accurate
# 6. Mention which column is a linear function and which is polynomial

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\gaura\Desktop\GOLD.csv')

# %%
df
# Out:
#              Date  Price   Open   High    Low    Vol. Change %   Pred  \
# 0    May 04, 2017  28060  28400  28482  28025   0.08K   -1.79%  738.0
# 1    May 05, 2017  28184  28136  28382  28135   0.06K    0.44% -146.0
# 2    May 08, 2017  28119  28145  28255  28097   7.85K   -0.23%   30.0
# 3    May 09, 2017  27981  28125  28192  27947  10.10K   -0.49%  357.0
# 4    May 10, 2017  28007  28060  28146  27981   9.28K    0.09%  124.0
# ..            ...    ...    ...    ...    ...     ...      ...    ...
# 507  Apr 26, 2019  31868  31851  31934  31705   9.67K    0.08%    NaN
# 508  Apr 30, 2019  31625  31800  31824  31597   6.44K   -0.76%    NaN
# 509  May 01, 2019  31563  31604  31657  31503   1.55K   -0.20%    NaN
# 510  May 02, 2019  31203  31420  31425  31160   0.48K   -1.14%    NaN
# 511  May 03, 2019  31341  31250  31500  31163   0.08K    0.44%    NaN
#
#             new
# 0    117.570740
# 1    295.430176
# 2    132.123714
# 3    101.298064
# 4    112.153318
# ..          ...
# ...

# %%
df.head()
# Out:
#            Date  Price   Open   High    Low    Vol. Change %   Pred  \
# 0  May 04, 2017  28060  28400  28482  28025   0.08K   -1.79%  738.0
# 1  May 05, 2017  28184  28136  28382  28135   0.06K    0.44% -146.0
# 2  May 08, 2017  28119  28145  28255  28097   7.85K   -0.23%   30.0
# 3  May 09, 2017  27981  28125  28192  27947  10.10K   -0.49%  357.0
# 4  May 10, 2017  28007  28060  28146  27981   9.28K    0.09%  124.0
#
#           new
# 0  117.570740
# 1  295.430176
# 2  132.123714
# 3  101.298064
# 4  112.153318

# %%
df.tail()
# Out:
#              Date  Price   Open   High    Low   Vol. Change %  Pred  \
# 507  Apr 26, 2019  31868  31851  31934  31705  9.67K    0.08%   NaN
# 508  Apr 30, 2019  31625  31800  31824  31597  6.44K   -0.76%   NaN
# 509  May 01, 2019  31563  31604  31657  31503  1.55K   -0.20%   NaN
# 510  May 02, 2019  31203  31420  31425  31160  0.48K   -1.14%   NaN
# 511  May 03, 2019  31341  31250  31500  31163  0.08K    0.44%   NaN
#
#             new
# 507  247.177322
# 508   52.201158
# 509  113.293305
# 510   48.365693
# 511  429.924911

# %%
df.describe()
# Out:
#               Price          Open          High           Low         Pred  \
# count    512.000000    512.000000    512.000000    512.000000   411.000000
# mean   30364.583984  30368.412109  30491.089844  30243.320312   341.712895
# std     1284.378623   1296.856656   1307.031684   1271.936410   271.075609
# min    27812.000000  27805.000000  27887.000000  27620.000000  -146.000000
# 25%    29432.500000  29436.750000  29499.750000  29345.750000   156.500000
# 50%    30427.500000  30399.500000  30545.000000  30286.000000   299.000000
# 75%    31271.750000  31300.000000  31447.500000  31160.750000   475.000000
# max    33753.000000  34247.000000  34400.000000  33680.000000  2210.000000
#
#                new
# count   512.000000
# mean    245.161859
# std     205.788897
# min      11.109814
# 25%     101.369172
# 50%     184.537244
# 75%     320.835031
# max    1407.321485

# %%
data.isnull().sum()
# Out:
# Date          0
# Price         0
# Open          0
# High          0
# Low           0
# Vol.          0
# Change %      0
# Pred        101
# new           0
# dtype: int64

# %%
for i,j in zip(df["Change %"],df.index):
    df["Change %"][j] = float(i.replace('%',''))
# Out:
# C:\Users\gaura\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df['Change %'] = df['Change %'].astype("float")

# %%
plt.figure(figsize=(17,5))
plt.plot(df['Price'])
plt.show()

# %%
Y_train = data['Pred'].dropna()

# %%
Y_train.shape
# Out:
# (411,)

# %%
X_train = data[['Open','High','Low','Price']][:411]

# %%
X_train.shape
# Out:
# (411, 4)

# %%
lr = LinearRegression(normalize=True,)
lr.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)

# %%
Y_train_pred = lr.predict(X_train)

# %%
acc_train = lr.score(X_train,Y_train)

# %%
acc_train
# Out:
# 1.0

# %%
from sklearn.preprocessing import StandardScaler

# %%
import seaborn as sns

# %%
sns.pairplot(X_train,diag_kind='hist')

# %%
pd.DataFrame(X_train)
# Out:
#       Open   High    Low  Price
# 0    28400  28482  28025  28060
# 1    28136  28382  28135  28184
# 2    28145  28255  28097  28119
# 3    28125  28192  27947  27981
# 4    28060  28146  27981  28007
# ..     ...    ...    ...    ...
# 406  30874  31085  30874  30964
# 407  30830  30970  30825  30926
# 408  31039  31196  30974  31005
# 409  31011  31480  30941  31440
# 410  31459  31966  31420  31895
#
# [411 rows x 4 columns]

# %%
X_train.corr()
# Out:
#            Open      High       Low     Price
# Open   1.000000  0.993764  0.994031  0.987029
# High   0.993764  1.000000  0.993850  0.995279
# Low    0.994031  0.993850  1.000000  0.995058
# Price  0.987029  0.995279  0.995058  1.000000

# %%
plt.hist(Y_train)
# Out:
# (array([ 61., 161., 119.,  44.,  19.,   4.,   1.,   1.,   0.,   1.]),
#  array([-146. ,   89.6,  325.2,  560.8,  796.4, 1032. , 1267.6, 1503.2,
#         1738.8, 1974.4, 2210. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(Y_train_pred)
# Out:
# (array([ 61., 161., 119.,  44.,  19.,   4.,   1.,   1.,   0.,   1.]),
#  array([-146. ,   89.6,  325.2,  560.8,  796.4, 1032. , 1267.6, 1503.2,
#         1738.8, 1974.4, 2210. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(df['new'])
# Out:
# (array([218., 136.,  83.,  39.,  15.,  10.,   4.,   6.,   0.,   1.]),
#  array([  11.10981387,  150.73098101,  290.35214815,  429.97331529,
#          569.59448242,  709.21564956,  848.8368167 ,  988.45798383,
#         1128.07915097, 1267.70031811, 1407.32148524]),
#  <a list of 10 Patch objects>)

# %%
pd.DataFrame(Y_train_pred)
# Out:
#          0
# 0    738.0
# 1   -146.0
# 2     30.0
# 3    357.0
# 4    124.0
# ..     ...
# 406  -31.0
# 407   72.0
# 408   35.0
# 409  669.0
# 410  521.0
#
# [411 rows x 1 columns]

# %%
pd.DataFrame(Y_train)
# Out:
#       Pred
# 0    738.0
# 1   -146.0
# 2     30.0
# 3    357.0
# 4    124.0
# ..     ...
# 406  -31.0
# 407   72.0
# 408   35.0
# 409  669.0
# 410  521.0
#
# [411 rows x 1 columns]

# %%
sns.distplot(Y_train)

# %%
sns.distplot(Y_train_pred)

# %%
sns.distplot(df['new'])

# %%
from sklearn.metrics import mean_squared_error

# %%
rmse = mean_squared_error(Y_train,Y_train_pred)

# %%
np.sqrt(rmse)
# Out:
# 1.2625394868524306e-11

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pol = PolynomialFeatures(degree = 2)

# %%
X_train_new = df[['Open','High','Low','Change %']]

# %%
Y_train_new = df['new']

# %%
Y_train_new = np.array(Y_train_new).reshape(-1,1)

# %%
X_train_poly = pol.fit_transform(X_train_new)

# %%
lr.fit(X_train_poly,Y_train_new)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)

# %%
r2_poly_new = lr.score(X_train_poly,Y_train_new)

# %%
r2_poly_new
# Out:
# 0.9396813203645529

# %%
Y_train_pred_poly_new = lr.predict(X_train_poly)

# %%
rmse_poly_new = np.sqrt(mean_squared_error(Y_train_new,Y_train_pred_poly_new))

# %%
rmse_poly_new
# Out:
# 50.49208709221437

# %%
sns.distplot(Y_train_new)

# %%
sns.distplot(Y_train_pred_poly_new)

# %%
#Linear model for predicting new column

# %%
X = df[['Open','High','Low','Price']]
Y = df['new']

# %%
lr = LinearRegression()

# %%
lr.fit(X,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
Y_pred = lr.predict(X)

# %%
r2 = lr.score(X,Y)

# %%
r2
# Out:
# 0.9999886649319772

# %%
plt.figure(figsize=(17,5))
plt.subplot(1,2,1)
sns.distplot(Y)
plt.subplot(1,2,2)
sns.distplot(Y_pred)

# %%
#Polynomial model for new column

# %%
X = df[['Open','High','Low','Price']]
Y = np.asarray(df['new']).reshape(-1,1)

# %%
poly = PolynomialFeatures(degree=2)

# %%
X_poly = poly.fit_transform(X)

# %%
Y = Y.reshape(-1,1)

# %%
lr.fit(X_poly,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
Y_pred = lr.predict(X_poly)

# %%
r2 = lr.score(X_poly,Y)

# %%
r2
# Out:
# 0.9999999919827844

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.distplot(Y)
plt.subplot(1,2,2)
sns.distplot(Y_pred)

# %%
#linear model for predicting the pred column

# %%
Y = np.asarray(df['Pred'].dropna())

# %%
print(Y.shape)
# Out:
# (411,)

# %%
X = df[['Open','High','Low','Price']][:411]

# %%
print(X.shape)
# Out:
# (411, 4)

# %%
lr = LinearRegression()

# %%
lr.fit(X,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
Y_pred = lr.predict(X)

# %%
r2 = lr.score(X,Y)

# %%
r2
# Out:
# 1.0

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.distplot(Y)
plt.subplot(1,2,2)
sns.distplot(Y_pred)

# %%
input_coeff = lr.intercept_

# %%
input_coeff
# Out:
# -5.360334398574196e-11

# %%
input_coeffs = lr.coef_

# %%
input_coeffs
# Out:
# array([ 3., -1., -4.,  2.])

# %%
X_test = df[['Open','High','Low','Price']][411:]

# %%
predictions = lr.predict(X_test)

# %%
pd.DataFrame(predictions,columns=['Pred'])
# Out:
#       Pred
# 0    852.0
# 1    422.0
# 2    530.0
# 3    144.0
# 4    415.0
# ..     ...
# 96   535.0
# 97   438.0
# 98   269.0
# 99   601.0
# 100  280.0
#
# [101 rows x 1 columns]

# %%
plt.figure(figsize=(15,5))
plt.plot(predictions)
plt.show()

# %%
dfc= df.copy()

# %%
dfc['Pred'][411:] = predictions
# Out:
# C:\Users\gaura\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dfc['Date'] = dfc['Date'].astype('datetime64')

# %%
dfc.set_index('Date',inplace=True)

# %%
plt.figure(figsize=(15,5))
plt.plot(dfc['Price'],color='y')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.plot(dfc['Pred'])
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.plot(dfc['new'])
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)

sns.distplot(dfc['Pred'])
plt.subplot(1,2,2)
sns.distplot(dfc['new'])

# %%
plt.figure(figsize=(15,5))
plt.scatter(dfc['Pred'],dfc['Low'])

# %%
plt.figure(figsize=(15,5))
plt.scatter(dfc['new'],dfc['Price'])

# %%
dfc['Pred'].mean()
# Out:
# 370.033203125

# %%
#Polynomial Model for Pred

# %%
poly = PolynomialFeatures(degree=5)

# %%
X_poly = poly.fit_transform(X)

# %%
Y = Y.reshape(-1,1)

# %%
lr.fit(X_poly,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
Y_pred = lr.predict(X_poly)

# %%
r2 = lr.score(X_poly,Y)

# %%
r2
# Out:
# 0.9999989275725484

# %%
plt.figure(figsize=(17,5))
plt.subplot(1,2,1)
sns.distplot(Y)
plt.subplot(1,2,2)
sns.distplot(Y_pred)

# %%
sns.distplot(dfc['new'])

# %%
dfc.isna().sum()
# Out:
# Price       0
# Open        0
# High        0
# Low         0
# Vol.        0
# Change %    0
# Pred        0
# new         0
# dtype: int64

# %%
plt.figure(figsize=(15,5))
plt.plot(dfc.index[:20],dfc['Pred'][:20],color='r',marker='^')
plt.plot(dfc.index[:20],dfc['new'][:20],color='b',marker='o')

# %%
#Hence, it is concluded that the pred column is linear and the new column is polynomial

# %%
#Poblem Statement 3.2
#To do - 
# 1. Import stock of your choosing and import nifty index
# 2. Calculate the daily beta value for the past 3 months using linear regression
# 3. Calculate the monthly beta value using linear regression
# 4. Include brief writeup regarding the results achieved

# %%
nifty = pd.read_csv(r'C:\Users\gaura\Desktop\Nifty50.csv')

# %%
nifty
# Out:
#             Date      Open      High       Low     Close  Shares Traded  \
# 0    15-May-2017   9433.55   9449.25   9423.10   9445.40      145163953
# 1    16-May-2017   9461.00   9517.20   9456.35   9512.25      171709433
# 2    17-May-2017   9517.60   9532.60   9486.10   9525.75      211856040
# 3    18-May-2017   9453.20   9489.10   9418.10   9429.45      199340647
# 4    19-May-2017   9469.90   9505.75   9390.75   9427.90      259861396
# ..           ...       ...       ...       ...       ...            ...
# 489  07-May-2019  11651.50  11657.05  11484.45  11497.90      337495624
# 490  08-May-2019  11478.70  11479.10  11346.95  11359.45      372826025
# 491  09-May-2019  11322.40  11357.60  11255.05  11301.80      373028059
# 492  10-May-2019  11314.15  11345.80  11251.05  11278.90      387323416
# 493  13-May-2019  11258.70  11300.20  11125.60  11148.20      357586433
#
#      Turnover (Rs. Cr)
# 0              7790.97
# 1              9209.89
# 2             10726.23
# ...

# %%
nifty["Day_perc_change"] = nifty['Close'].pct_change()*100

# %%
nifty['Day_perc_change'].fillna(0,inplace=True)

# %%
nifty['Date'] = nifty['Date'].astype('datetime64')

# %%
nifty.set_index('Date',inplace = True)

# %%
dfw = pd.read_csv(r'C:\Users\gaura\Desktop\week2.csv')

# %%
X = nifty['Day_perc_change'][-90:]

# %%
X
# Out:
# Date
# 2018-12-31    0.024402
# 2019-01-01    0.437743
# 2019-01-02   -1.077900
# 2019-01-03   -1.114200
# 2019-01-04    0.516292
#                 ...
# 2019-05-07   -0.865217
# 2019-05-08   -1.204133
# 2019-05-09   -0.507507
# 2019-05-10   -0.202623
# 2019-05-13   -1.158801
# Name: Day_perc_change, Length: 90, dtype: float64

# %%
Y = dfw['Day_Perc_Change'][-90:]

# %%
Y
# Out:
# 326   -0.003504
# 327    0.017582
# 328   -0.028510
# 329   -0.020454
# 330    0.008625
#          ...
# 411   -0.065050
# 412   -0.017291
# 413   -0.013406
# 414   -0.005945
# 415   -0.061512
# Name: Day_Perc_Change, Length: 90, dtype: float64

# %%
lr = LinearRegression()

# %%
lr.fit(np.asarray(X).reshape(-1,1),np.asarray(Y).reshape(-1,1))
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
beta = lr.coef_

# %%
beta
# Out:
# array([[0.01888044]])

# %%
Y_pred = lr.predict(np.asarray(X).reshape(-1,1))

# %%
plt.figure(figsize=(15,5))
plt.scatter(X,Y)
plt.plot(X,Y_pred,color='r')
plt.title('Daily for past 3 Months Beta Calculation')
plt.show()

# %%
Y =[]
for i in range(0,416,30):
    Y.append(dfw['Close Price'][i])

# %%
Y = np.asarray(Y)

# %%
Y.shape
# Out:
# (14,)

# %%
Y = pd.DataFrame(Y)

# %%
Y['Monthly Returns'] = Y.pct_change()*100

# %%
Y.fillna(0,inplace=True)

# %%
nifty.head()
# Out:
#                Open     High      Low    Close  Shares Traded  \
# Date
# 2017-05-15  9433.55  9449.25  9423.10  9445.40      145163953
# 2017-05-16  9461.00  9517.20  9456.35  9512.25      171709433
# 2017-05-17  9517.60  9532.60  9486.10  9525.75      211856040
# 2017-05-18  9453.20  9489.10  9418.10  9429.45      199340647
# 2017-05-19  9469.90  9505.75  9390.75  9427.90      259861396
#
#             Turnover (Rs. Cr)  Day_perc_change
# Date
# 2017-05-15            7790.97         0.000000
# 2017-05-16            9209.89         0.707752
# 2017-05-17           10726.23         0.141922
# 2017-05-18           10782.46        -1.010944
# 2017-05-19           11544.77        -0.016438

# %%
X =[]
for i in range(0,416,30):
    X.append(nifty['Close'][i])

# %%
X = pd.DataFrame(X)

# %%
X['Monthly Return'] = X.pct_change()*100

# %%
X.fillna(0,inplace=True)

# %%
print(X.shape,Y.shape)
# Out:
# (14, 2) (14, 2)

# %%
X = X['Monthly Return']
Y = Y['Monthly Returns']

# %%
print(X.shape,Y.shape)
# Out:
# (14,) (14,)

# %%
lr.fit(np.asarray(X).reshape(-1,1),np.asarray(Y).reshape(-1,1))
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
beta_monthly = lr.coef_

# %%
beta_monthly
# Out:
# array([[-0.0639936]])

# %%
Y_pred = lr.predict(np.asarray(X).reshape(-1,1))

# %%
plt.figure(figsize=(17,5))
plt.scatter(X,Y)
plt.plot(X,Y_pred,color='r')
plt.title('Monthly Beta Calculation')
plt.show()

# %%
#Beta is a measure of a stock's volatility. A stock that swings more than the market over time has a beta above 1.0 
#which means it is a riskier stock. If a stock moves less than the market, the stock's beta is less than 1.0. If the 
#value is negative, it means that the stock is moving in the opposite direction of the market.
